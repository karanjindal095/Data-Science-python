# %% [markdown]
# Univariate

# %%
import numpy as np
import pandas as py
import matplotlib.pyplot as plt
import seaborn as sb
tips = sb.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sb.set_style("darkgrid")

# %% [markdown]
# 01 histplot()

# %%
sb.histplot(x= "total_bill",data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
# bins=  :set size of histogram 
sb.histplot(x= "total_bill",data=tips,bins=30)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# 02 Kdeplot

# %%
sb.kdeplot(x= "tip",data=tips)
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %% [markdown]
# 03 displot()

# %%
sb.displot(tips["total_bill"])

# %% [markdown]
# 04 countplot

# %%
sb.countplot(x='total_bill',data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='count'>

# %%
sb.countplot(x='size',data=tips)
# Out:
# <Axes: xlabel='size', ylabel='count'>

# %% [markdown]
# 05 palette= ' colors '
# #flare
# #magma
# #crest
# #viridis
# #cubehelix

# %%
sb.countplot(x= "total_bill",data=tips,palette="flare")
# Out:
# <Axes: xlabel='total_bill', ylabel='count'>
